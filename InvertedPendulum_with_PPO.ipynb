# %% [markdown]
# # Half Cheetah Choosing Random Actions

# %%
# !pip install matplotlib
# !pip install tensorboardX

# %%
# import gym
# import random
# import numpy as np

# env = gym.make("HalfCheetah-v2")

# def Random_games():
#     # Each of this episode is its own game.
#     action_size = env.action_space.shape[0]
#     for episode in range(10):
#         env.reset()
#         # this is each frame, up to 500...but we wont make it that far with random.
#         while True:
#             # This will display the environment
#             # Only display if you really want to see it.
#             # Takes much longer to display it.
#             env.render()
            
#             # This will just create a sample action in any environment.
#             # In this environment, the action can be any of one how in list on 4, for example [0 1 0 0]
#             action = np.random.uniform(-1.0, 1.0, size=action_size)

#             # this executes the environment with an action, 
#             # and returns the observation of the environment, 
#             # the reward, if the env is over, and other info.
#             next_state, reward, done, info = env.step(action)
            
#             # lets print everything in one line:
#             #print(reward, action)
#             if done:
#                 break
                
# Random_games()

# %% [markdown]
# # Inverted Pendulum using Proximal Policy Optimization

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # -1:cpu, 0:first gpu
import random
import gym
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorboardX import SummaryWriter
#tf.config.experimental_run_functions_eagerly(True) # used for debuging and development
tf.compat.v1.disable_eager_execution() # usually using this for fastest performance
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop, Adagrad, Adadelta
from tensorflow.keras import backend as K
import copy

from threading import Thread, Lock
from multiprocessing import Process, Pipe
import time

gpus = tf.config.experimental.list_physical_devices('GPU')
if len(gpus) > 0:
    print(f'GPUs {gpus}')
    try: tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError: pass
    
global_clip = 100

class Environment(Process):
    def __init__(self, env_idx, child_conn, env_name, state_size, action_size, visualize=False):
        super(Environment, self).__init__()
        self.env = gym.make(env_name)
        self.is_render = visualize
        self.env_idx = env_idx
        self.child_conn = child_conn
        self.state_size = state_size
        self.action_size = action_size

    def run(self):
        super(Environment, self).run()
        state = self.env.reset()
        state = np.reshape(state, [1, self.state_size])
        self.child_conn.send(state)
        while True:
            action = self.child_conn.recv()
            #if self.is_render and self.env_idx == 0:
                #self.env.render()

            state, reward, done, info = self.env.step(action)
            state = np.reshape(state, [1, self.state_size])

            if done:
                state = self.env.reset()
                state = np.reshape(state, [1, self.state_size])

            self.child_conn.send([state, reward, done, info])


class Actor_Model:
    def __init__(self, input_shape, action_space, lr, optimizer):
        X_input = Input(input_shape)
        self.action_space = action_space
        
        X = Dense(512, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X_input)
        X = Dense(256, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        X = Dense(64, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        output = Dense(self.action_space, activation="tanh")(X)

        self.Actor = Model(inputs = X_input, outputs = output)
        self.Actor.compile(loss=self.ppo_loss_continuous, optimizer=optimizer(lr=lr))
        #print(self.Actor.summary())

    def ppo_loss_continuous(self, y_true, y_pred):
        advantages, actions, logp_old_ph, = y_true[:, :1], y_true[:, 1:1+self.action_space], y_true[:, 1+self.action_space]
        LOSS_CLIPPING = global_clip
        logp = self.gaussian_likelihood(actions, y_pred)

        ratio = K.exp(logp - logp_old_ph)

        p1 = ratio * advantages
        p2 = tf.where(advantages > 0, (1.0 + LOSS_CLIPPING)*advantages, (1.0 - LOSS_CLIPPING)*advantages) # minimum advantage

        actor_loss = -K.mean(K.minimum(p1, p2))

        return actor_loss

    def gaussian_likelihood(self, actions, pred): # for keras custom loss
        log_std = -0.5 * np.ones(self.action_space, dtype=np.float32)
        pre_sum = -0.5 * (((actions-pred)/(K.exp(log_std)+1e-8))**2 + 2*log_std + K.log(2*np.pi))
        return K.sum(pre_sum, axis=1)

    def predict(self, state):
        return self.Actor.predict(state)


class Critic_Model:
    def __init__(self, input_shape, action_space, lr, optimizer):
        X_input = Input(input_shape)
        old_values = Input(shape=(1,))

        V = Dense(512, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X_input)
        V = Dense(256, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(V)
        V = Dense(64, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(V)
        value = Dense(1, activation=None)(V)

        self.Critic = Model(inputs=[X_input, old_values], outputs = value)
        self.Critic.compile(loss=[self.critic_PPO2_loss(old_values)], optimizer=optimizer(lr=lr))

    def critic_PPO2_loss(self, values):
        def loss(y_true, y_pred):
            LOSS_CLIPPING = global_clip
            clipped_value_loss = values + K.clip(y_pred - values, -LOSS_CLIPPING, LOSS_CLIPPING)
            v_loss1 = (y_true - clipped_value_loss) ** 2
            v_loss2 = (y_true - y_pred) ** 2
            
            value_loss = 0.5 * K.mean(K.maximum(v_loss1, v_loss2))
            #value_loss = K.mean((y_true - y_pred) ** 2) # standard PPO loss
            return value_loss
        return loss

    def predict(self, state):
        return self.Critic.predict([state, np.zeros((state.shape[0], 1))])
    

class PPOAgent:
    # PPO Main Optimization Algorithm
    def __init__(self, env_name, model_name=""):
        # Initialization
        # Environment and PPO parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.action_size = self.env.action_space.shape[0]
        self.state_size = self.env.observation_space.shape
        self.EPISODES = 600 # total episodes to train through all environments
        self.episode = 0 # used to track the episodes total count of episodes played through all thread environments
        self.max_average = 0 # when average score is above 0 model will be saved
        self.lr = 0.00025
        self.epochs = 20 # training epochs
        self.shuffle = True
        self.Training_batch = 512
        #self.optimizer = RMSprop
        self.optimizer = Adam

        self.replay_count = 0
        self.writer = SummaryWriter(comment="_"+self.env_name+"_"+self.optimizer.__name__+"_"+str(self.lr))
        
        # Instantiate plot memory
        self.scores_, self.episodes_, self.average_ = [], [], [] # used in matplotlib plots

        # Create Actor-Critic network models
        self.Actor = Actor_Model(input_shape=self.state_size, action_space = self.action_size, lr=self.lr, optimizer = self.optimizer)
        self.Critic = Critic_Model(input_shape=self.state_size, action_space = self.action_size, lr=self.lr, optimizer = self.optimizer)
        
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"
        #self.load() # uncomment to continue training from old weights

        # do not change bellow
        self.log_std = -0.5 * np.ones(self.action_size, dtype=np.float32)
        self.std = np.exp(self.log_std)


    def act(self, state):
        # Use the network to predict the next action to take, using the model
        pred = self.Actor.predict(state)

        low, high = -1.0, 1.0 # -1 and 1 are boundaries of tanh
        action = pred + np.random.uniform(low, high, size=pred.shape) * self.std
        action = np.clip(action, low, high)
        
        logp_t = self.gaussian_likelihood(action, pred, self.log_std)

        return action, logp_t

    def gaussian_likelihood(self, action, pred, log_std):
        # https://github.com/hill-a/stable-baselines/blob/master/stable_baselines/sac/policies.py
        pre_sum = -0.5 * (((action-pred)/(np.exp(log_std)+1e-8))**2 + 2*log_std + np.log(2*np.pi)) 
        return np.sum(pre_sum, axis=1)

    def discount_rewards(self, reward):#gaes is better
        # Compute the gamma-discounted rewards over an episode
        # We apply the discount and normalize it to avoid big variability of rewards
        gamma = 0.99    # discount rate
        running_add = 0
        discounted_r = np.zeros_like(reward)
        for i in reversed(range(0,len(reward))):
            running_add = running_add * gamma + reward[i]
            discounted_r[i] = running_add

        discounted_r -= np.mean(discounted_r) # normalizing the result
        discounted_r /= (np.std(discounted_r) + 1e-8) # divide by standard deviation
        return discounted_r

    def get_gaes(self, rewards, dones, values, next_values, gamma = 0.99, lamda = 0.90, normalize=True):
        deltas = [r + gamma * (1 - d) * nv - v for r, d, nv, v in zip(rewards, dones, next_values, values)]
        deltas = np.stack(deltas)
        gaes = copy.deepcopy(deltas)
        for t in reversed(range(len(deltas) - 1)):
            gaes[t] = gaes[t] + (1 - dones[t]) * gamma * lamda * gaes[t + 1]

        target = gaes + values
        if normalize:
            gaes = (gaes - gaes.mean()) / (gaes.std() + 1e-8)
        return np.vstack(gaes), np.vstack(target)

    def replay(self, states, actions, rewards, dones, next_states, logp_ts):
        # reshape memory to appropriate shape for training
        states = np.vstack(states)
        next_states = np.vstack(next_states)
        actions = np.vstack(actions)
        logp_ts = np.vstack(logp_ts)

        # Get Critic network predictions 
        values = self.Critic.predict(states)
        next_values = self.Critic.predict(next_states)

        # Compute discounted rewards and advantages
        #discounted_r = self.discount_rewards(rewards)
        #advantages = np.vstack(discounted_r - values)
        advantages, target = self.get_gaes(rewards, dones, np.squeeze(values), np.squeeze(next_values))
        '''
        pylab.plot(adv,'.')
        pylab.plot(target,'-')
        ax=pylab.gca()
        ax.grid(True)
        pylab.subplots_adjust(left=0.05, right=0.98, top=0.96, bottom=0.06)
        pylab.show()
        if str(episode)[-2:] == "00": pylab.savefig(self.env_name+"_"+self.episode+".png")
        '''
        # stack everything to numpy array
        # pack all advantages, predictions and actions to y_true and when they are received
        # in custom loss function we unpack it
        y_true = np.hstack([advantages, actions, logp_ts])
        
        # training Actor and Critic networks
        a_loss = self.Actor.Actor.fit(states, y_true, epochs=self.epochs, verbose=0, shuffle=self.shuffle)
        c_loss = self.Critic.Critic.fit([states, values], target, epochs=self.epochs, verbose=0, shuffle=self.shuffle)

        # calculate loss parameters (should be done in loss, but couldn't find working way how to do that with disabled eager execution)
        pred = self.Actor.predict(states)
        log_std = -0.5 * np.ones(self.action_size, dtype=np.float32)
        logp = self.gaussian_likelihood(actions, pred, log_std)
        approx_kl = np.mean(logp_ts - logp)
        approx_ent = np.mean(-logp)

        self.writer.add_scalar('Data/actor_loss_per_replay', np.sum(a_loss.history['loss']), self.replay_count)
        self.writer.add_scalar('Data/critic_loss_per_replay', np.sum(c_loss.history['loss']), self.replay_count)
        self.writer.add_scalar('Data/approx_kl_per_replay', approx_kl, self.replay_count)
        self.writer.add_scalar('Data/approx_ent_per_replay', approx_ent, self.replay_count)
        self.replay_count += 1
 
    def load(self):
        self.Actor.Actor.load_weights(self.Actor_name)
        self.Critic.Critic.load_weights(self.Critic_name)

    def save(self):
        self.Actor.Actor.save_weights(self.Actor_name)
        self.Critic.Critic.save_weights(self.Critic_name)

    plt.figure(figsize=(18, 9))
    plt.subplots_adjust(left=0.05, right=0.98, top=0.96, bottom=0.06)
    def PlotModel(self, score, episode, save=True):
        self.scores_.append(score)
        self.episodes_.append(episode)
        self.average_.append(sum(self.scores_[-50:]) / len(self.scores_[-50:]))
        if str(episode)[-2:] == "00":# much faster than episode % 100
            plt.plot(self.episodes_, self.scores_, 'b')
            plt.plot(self.episodes_, self.average_, 'r')
            plt.ylabel('Score', fontsize=18)
            plt.xlabel('Steps', fontsize=18)
            try:
                plt.grid(True)
                plt.savefig(self.env_name+".png")
            except OSError:
                pass
        # saving best models
        if self.average_[-1] >= self.max_average and save:
            self.max_average = self.average_[-1]
            self.save()
            SAVING = "SAVING"
            # decrease learning rate every saved model
            #self.lr *= 0.99
            #K.set_value(self.Actor.Actor.optimizer.learning_rate, self.lr)
            #K.set_value(self.Critic.Critic.optimizer.learning_rate, self.lr)
        else:
            SAVING = ""

        return self.average_[-1], SAVING
    
    def run_batch(self):
        state = self.env.reset()
        state = np.reshape(state, [1, self.state_size[0]])
        done, score, SAVING = False, 0, ''
        while True:
            # Instantiate or reset games memory
            states, next_states, actions, rewards, dones, logp_ts = [], [], [], [], [], []
            for t in range(self.Training_batch):
                #self.env.render()
                # Actor picks an action
                action, logp_t = self.act(state)
                # Retrieve new state, reward, and whether the state is terminal
                next_state, reward, done, _ = self.env.step(action[0])
                # Memorize (state, next_states, action, reward, done, logp_ts) for training
                states.append(state)
                next_states.append(np.reshape(next_state, [1, self.state_size[0]]))
                actions.append(action)
                rewards.append(reward)
                dones.append(done)
                logp_ts.append(logp_t[0])
                # Update current state shape
                state = np.reshape(next_state, [1, self.state_size[0]])
                score += reward
                if done:
                    self.episode += 1
                    average, SAVING = self.PlotModel(score, self.episode)
                    print("episode: {}/{}, score: {}, average: {:.2f} {}".format(self.episode, self.EPISODES, score, average, SAVING))
                    self.writer.add_scalar(f'Workers:{1}/score_per_episode', score, self.episode)
                    self.writer.add_scalar(f'Workers:{1}/learning_rate', self.lr, self.episode)
                    self.writer.add_scalar(f'Workers:{1}/average_score',  average, self.episode)
                    
                    state, done, score, SAVING = self.env.reset(), False, 0, ''
                    state = np.reshape(state, [1, self.state_size[0]])

            self.replay(states, actions, rewards, dones, next_states, logp_ts)
            if self.episode >= self.EPISODES:
                break

        self.env.close()


    def run_multiprocesses(self, num_worker = 4):
        works, parent_conns, child_conns = [], [], []
        for idx in range(num_worker):
            parent_conn, child_conn = Pipe()
            work = Environment(idx, child_conn, self.env_name, self.state_size[0], self.action_size, True)
            work.start()
            works.append(work)
            parent_conns.append(parent_conn)
            child_conns.append(child_conn)

        states =        [[] for _ in range(num_worker)]
        next_states =   [[] for _ in range(num_worker)]
        actions =       [[] for _ in range(num_worker)]
        rewards =       [[] for _ in range(num_worker)]
        dones =         [[] for _ in range(num_worker)]
        logp_ts =       [[] for _ in range(num_worker)]
        score =         [0 for _ in range(num_worker)]

        state = [0 for _ in range(num_worker)]
        for worker_id, parent_conn in enumerate(parent_conns):
            state[worker_id] = parent_conn.recv()

        while self.episode < self.EPISODES:
            # get batch of action's and log_pi's
            action, logp_pi = self.act(np.reshape(state, [num_worker, self.state_size[0]]))
            
            for worker_id, parent_conn in enumerate(parent_conns):
                parent_conn.send(action[worker_id])
                actions[worker_id].append(action[worker_id])
                logp_ts[worker_id].append(logp_pi[worker_id])

            for worker_id, parent_conn in enumerate(parent_conns):
                next_state, reward, done, _ = parent_conn.recv()

                states[worker_id].append(state[worker_id])
                next_states[worker_id].append(next_state)
                rewards[worker_id].append(reward)
                dones[worker_id].append(done)
                state[worker_id] = next_state
                score[worker_id] += reward

                if done:
                    average, SAVING = self.PlotModel(score[worker_id], self.episode)
                    print("episode: {}/{}, worker: {}, score: {}, average: {:.2f} {}".format(self.episode, self.EPISODES, worker_id, score[worker_id], average, SAVING))
                    self.writer.add_scalar(f'Workers:{num_worker}/score_per_episode', score[worker_id], self.episode)
                    self.writer.add_scalar(f'Workers:{num_worker}/learning_rate', self.lr, self.episode)
                    self.writer.add_scalar(f'Workers:{num_worker}/average_score',  average, self.episode)
                    score[worker_id] = 0
                    if(self.episode < self.EPISODES):
                        self.episode += 1
                        
                        
            for worker_id in range(num_worker):
                if len(states[worker_id]) >= self.Training_batch:
                    self.replay(states[worker_id], actions[worker_id], rewards[worker_id], dones[worker_id], next_states[worker_id], logp_ts[worker_id])

                    states[worker_id] = []
                    next_states[worker_id] = []
                    actions[worker_id] = []
                    rewards[worker_id] = []
                    dones[worker_id] = []
                    logp_ts[worker_id] = []

        # terminating processes after a while loop
        works.append(work)
        for work in works:
            work.terminate()
            print('TERMINATED:', work)
            work.join()

    def test(self, test_episodes = 50):#evaluate
        self.load()
        for e in range(51):
            state = self.env.reset()
            state = np.reshape(state, [1, self.state_size[0]])
            done = False
            score = 0
            while not done:
                self.env.render()
                action = self.Actor.predict(state)[0]
                state, reward, done, _ = self.env.step(action)
                state = np.reshape(state, [1, self.state_size[0]])
                score += reward
                if done:
                    average, SAVING = self.PlotModel(score, e, save=False)
                    print("episode: {}/{}, score: {}, average{}".format(e, test_episodes, score, average))
                    break
        self.env.close()
            

if __name__ == "__main__":
    env_name = 'InvertedPendulum-v2'
    agent = PPOAgent(env_name)
    agent.run_batch() # train as PPO
    #agent.run_multiprocesses(num_worker = 16)  # train PPO multiprocessed (fastest)
    #agent.test()
# Out:
# /home/darren/anaconda3/envs/gym/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/darren/anaconda3/envs/gym/lib/python3.6/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /home/darren/anaconda3/envs/gym/lib/python3.6/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# episode: 1/600, score: 10.0, average: 10.00 SAVING
# episode: 2/600, score: 8.0, average: 9.00
# episode: 3/600, score: 7.0, average: 8.33
# episode: 4/600, score: 20.0, average: 11.25 SAVING
# episode: 5/600, score: 11.0, average: 11.20
# episode: 6/600, score: 9.0, average: 10.83
# episode: 7/600, score: 14.0, average: 11.29 SAVING
# episode: 8/600, score: 15.0, average: 11.75 SAVING
# episode: 9/600, score: 12.0, average: 11.78 SAVING
# episode: 10/600, score: 8.0, average: 11.40
# episode: 11/600, score: 10.0, average: 11.27
# episode: 12/600, score: 8.0, average: 11.00
# episode: 13/600, score: 7.0, average: 10.69
# episode: 14/600, score: 15.0, average: 11.00
# episode: 15/600, score: 14.0, average: 11.20
# episode: 16/600, score: 7.0, average: 10.94
# episode: 17/600, score: 12.0, average: 11.00
# episode: 18/600, score: 9.0, average: 10.89
# episode: 19/600, score: 12.0, average: 10.95
# episode: 20/600, score: 22.0, average: 11.50
# episode: 21/600, score: 28.0, average: 12.29 SAVING
# episode: 22/600, score: 11.0, average: 12.23
# episode: 23/600, score: 8.0, average: 12.04
# episode: 24/600, score: 17.0, average: 12.25
# episode: 25/600, score: 10.0, average: 12.16
# episode: 26/600, score: 10.0, average: 12.08
# episode: 27/600, score: 10.0, average: 12.00
# episode: 28/600, score: 11.0, average: 11.96
# episode: 29/600, score: 10.0, average: 11.90
# episode: 30/600, score: 12.0, average: 11.90
# episode: 31/600, score: 10.0, average: 11.84
# episode: 32/600, score: 14.0, average: 11.91
# episode: 33/600, score: 11.0, average: 11.88
# episode: 34/600, score: 9.0, average: 11.79
# episode: 35/600, score: 8.0, average: 11.69
# episode: 36/600, score: 9.0, average: 11.61
# episode: 37/600, score: 14.0, average: 11.68
# episode: 38/600, score: 12.0, average: 11.68
# episode: 39/600, score: 14.0, average: 11.74
# episode: 40/600, score: 7.0, average: 11.62
# episode: 41/600, score: 19.0, average: 11.80
# episode: 42/600, score: 20.0, average: 12.00
# episode: 43/600, score: 9.0, average: 11.93
# episode: 44/600, score: 11.0, average: 11.91
# episode: 45/600, score: 8.0, average: 11.82
# episode: 46/600, score: 11.0, average: 11.80
# episode: 47/600, score: 9.0, average: 11.74
# episode: 48/600, score: 12.0, average: 11.75
# episode: 49/600, score: 11.0, average: 11.73
# episode: 50/600, score: 10.0, average: 11.70
# episode: 51/600, score: 8.0, average: 11.66
# episode: 52/600, score: 7.0, average: 11.64
# episode: 53/600, score: 8.0, average: 11.66
# episode: 54/600, score: 8.0, average: 11.42
# episode: 55/600, score: 8.0, average: 11.36
# episode: 56/600, score: 16.0, average: 11.50
# episode: 57/600, score: 8.0, average: 11.38
# episode: 58/600, score: 13.0, average: 11.34
# episode: 59/600, score: 12.0, average: 11.34
# episode: 60/600, score: 22.0, average: 11.62
# episode: 61/600, score: 16.0, average: 11.74
# episode: 62/600, score: 19.0, average: 11.96
# episode: 63/600, score: 6.0, average: 11.94
# episode: 64/600, score: 13.0, average: 11.90
# episode: 65/600, score: 27.0, average: 12.16
# episode: 66/600, score: 10.0, average: 12.22
# episode: 67/600, score: 16.0, average: 12.30 SAVING
# episode: 68/600, score: 8.0, average: 12.28
# episode: 69/600, score: 8.0, average: 12.20
# episode: 70/600, score: 12.0, average: 12.00
# episode: 71/600, score: 22.0, average: 11.88
# episode: 72/600, score: 11.0, average: 11.88
# episode: 73/600, score: 9.0, average: 11.90
# episode: 74/600, score: 28.0, average: 12.12
# episode: 75/600, score: 7.0, average: 12.06
# episode: 76/600, score: 20.0, average: 12.26
# episode: 77/600, score: 23.0, average: 12.52 SAVING
# episode: 78/600, score: 19.0, average: 12.68 SAVING
# episode: 79/600, score: 23.0, average: 12.94 SAVING
# episode: 80/600, score: 17.0, average: 13.04 SAVING
# episode: 81/600, score: 9.0, average: 13.02
# episode: 82/600, score: 20.0, average: 13.14 SAVING
# episode: 83/600, score: 23.0, average: 13.38 SAVING
# episode: 84/600, score: 15.0, average: 13.50 SAVING
# episode: 85/600, score: 25.0, average: 13.84 SAVING
# episode: 86/600, score: 35.0, average: 14.36 SAVING
# episode: 87/600, score: 22.0, average: 14.52 SAVING
# episode: 88/600, score: 24.0, average: 14.76 SAVING
# episode: 89/600, score: 22.0, average: 14.92 SAVING
# episode: 90/600, score: 51.0, average: 15.80 SAVING
# episode: 91/600, score: 21.0, average: 15.84 SAVING
# episode: 92/600, score: 7.0, average: 15.58
# episode: 93/600, score: 16.0, average: 15.72
# episode: 94/600, score: 11.0, average: 15.72
# episode: 95/600, score: 36.0, average: 16.28 SAVING
# episode: 96/600, score: 11.0, average: 16.28 SAVING
# episode: 97/600, score: 50.0, average: 17.10 SAVING
# episode: 98/600, score: 25.0, average: 17.36 SAVING
# episode: 99/600, score: 17.0, average: 17.48 SAVING
# episode: 100/600, score: 30.0, average: 17.88 SAVING
# episode: 101/600, score: 30.0, average: 18.32 SAVING
# episode: 102/600, score: 37.0, average: 18.92 SAVING
# episode: 103/600, score: 10.0, average: 18.96 SAVING
# episode: 104/600, score: 14.0, average: 19.08 SAVING
# episode: 105/600, score: 14.0, average: 19.20 SAVING
# episode: 106/600, score: 11.0, average: 19.10
# episode: 107/600, score: 10.0, average: 19.14
# episode: 108/600, score: 9.0, average: 19.06
# episode: 109/600, score: 7.0, average: 18.96
# episode: 110/600, score: 9.0, average: 18.70
# episode: 111/600, score: 9.0, average: 18.56
# episode: 112/600, score: 8.0, average: 18.34
# episode: 113/600, score: 11.0, average: 18.44
# episode: 114/600, score: 11.0, average: 18.40
# episode: 115/600, score: 6.0, average: 17.98
# episode: 116/600, score: 11.0, average: 18.00
# episode: 117/600, score: 6.0, average: 17.80
# episode: 118/600, score: 12.0, average: 17.88
# episode: 119/600, score: 12.0, average: 17.96
# episode: 120/600, score: 12.0, average: 17.96
# episode: 121/600, score: 9.0, average: 17.70
# episode: 122/600, score: 6.0, average: 17.60
# episode: 123/600, score: 9.0, average: 17.60
# episode: 124/600, score: 6.0, average: 17.16
# episode: 125/600, score: 9.0, average: 17.20
# episode: 126/600, score: 9.0, average: 16.98
# episode: 127/600, score: 9.0, average: 16.70
# episode: 128/600, score: 7.0, average: 16.46
# episode: 129/600, score: 13.0, average: 16.26
# episode: 130/600, score: 7.0, average: 16.06
# episode: 131/600, score: 9.0, average: 16.06
# episode: 132/600, score: 9.0, average: 15.84
# episode: 133/600, score: 7.0, average: 15.52
# episode: 134/600, score: 6.0, average: 15.34
# episode: 135/600, score: 11.0, average: 15.06
# episode: 136/600, score: 8.0, average: 14.52
# episode: 137/600, score: 10.0, average: 14.28
# episode: 138/600, score: 9.0, average: 13.98
# episode: 139/600, score: 14.0, average: 13.82
# episode: 140/600, score: 7.0, average: 12.94
# episode: 141/600, score: 10.0, average: 12.72
# episode: 142/600, score: 12.0, average: 12.82
# episode: 143/600, score: 12.0, average: 12.74
# episode: 144/600, score: 6.0, average: 12.64
# episode: 145/600, score: 6.0, average: 12.04
# episode: 146/600, score: 10.0, average: 12.02
# episode: 147/600, score: 9.0, average: 11.20
# episode: 148/600, score: 6.0, average: 10.82
# episode: 149/600, score: 7.0, average: 10.62
# episode: 150/600, score: 10.0, average: 10.22
# episode: 151/600, score: 8.0, average: 9.78
# episode: 152/600, score: 9.0, average: 9.22
# episode: 153/600, score: 8.0, average: 9.18
# episode: 154/600, score: 7.0, average: 9.04
# episode: 155/600, score: 7.0, average: 8.90
# episode: 156/600, score: 9.0, average: 8.86
# episode: 157/600, score: 9.0, average: 8.84
# episode: 158/600, score: 21.0, average: 9.08
# episode: 159/600, score: 23.0, average: 9.40
# episode: 160/600, score: 20.0, average: 9.62
# episode: 161/600, score: 21.0, average: 9.86
# episode: 162/600, score: 20.0, average: 10.10
# episode: 163/600, score: 19.0, average: 10.26
# episode: 164/600, score: 16.0, average: 10.36
# episode: 165/600, score: 24.0, average: 10.72
# episode: 166/600, score: 19.0, average: 10.88
# episode: 167/600, score: 12.0, average: 11.00
# episode: 168/600, score: 23.0, average: 11.22
# episode: 169/600, score: 24.0, average: 11.46
# episode: 170/600, score: 14.0, average: 11.50
# episode: 171/600, score: 22.0, average: 11.76
# episode: 172/600, score: 25.0, average: 12.14
# episode: 173/600, score: 21.0, average: 12.38
# episode: 174/600, score: 22.0, average: 12.70
# episode: 175/600, score: 21.0, average: 12.94
# episode: 176/600, score: 20.0, average: 13.16
# episode: 177/600, score: 20.0, average: 13.38
# episode: 178/600, score: 21.0, average: 13.66
# episode: 179/600, score: 23.0, average: 13.86
# episode: 180/600, score: 20.0, average: 14.12
# episode: 181/600, score: 22.0, average: 14.38
# episode: 182/600, score: 28.0, average: 14.76
# episode: 183/600, score: 48.0, average: 15.58
# episode: 184/600, score: 36.0, average: 16.18
# episode: 185/600, score: 25.0, average: 16.46
# episode: 186/600, score: 39.0, average: 17.08
# episode: 187/600, score: 32.0, average: 17.52
# episode: 188/600, score: 58.0, average: 18.50
# episode: 189/600, score: 27.0, average: 18.76
# episode: 190/600, score: 41.0, average: 19.44 SAVING
# episode: 191/600, score: 33.0, average: 19.90 SAVING
# episode: 192/600, score: 31.0, average: 20.28 SAVING
# episode: 193/600, score: 25.0, average: 20.54 SAVING
# episode: 194/600, score: 36.0, average: 21.14 SAVING
# episode: 195/600, score: 35.0, average: 21.72 SAVING
# episode: 196/600, score: 23.0, average: 21.98 SAVING
# episode: 197/600, score: 64.0, average: 23.08 SAVING
# episode: 198/600, score: 22.0, average: 23.40 SAVING
# episode: 199/600, score: 41.0, average: 24.08 SAVING
# episode: 200/600, score: 31.0, average: 24.50 SAVING
# episode: 201/600, score: 36.0, average: 25.06 SAVING
# episode: 202/600, score: 28.0, average: 25.44 SAVING
# episode: 203/600, score: 43.0, average: 26.14 SAVING
# episode: 204/600, score: 38.0, average: 26.76 SAVING
# episode: 205/600, score: 28.0, average: 27.18 SAVING
# episode: 206/600, score: 32.0, average: 27.64 SAVING
# episode: 207/600, score: 34.0, average: 28.14 SAVING
# episode: 208/600, score: 27.0, average: 28.26 SAVING
# episode: 209/600, score: 30.0, average: 28.40 SAVING
# episode: 210/600, score: 43.0, average: 28.86 SAVING
# episode: 211/600, score: 46.0, average: 29.36 SAVING
# episode: 212/600, score: 82.0, average: 30.60 SAVING
# episode: 213/600, score: 97.0, average: 32.16 SAVING
# episode: 214/600, score: 86.0, average: 33.56 SAVING
# episode: 215/600, score: 97.0, average: 35.02 SAVING
# episode: 216/600, score: 123.0, average: 37.10 SAVING
# episode: 217/600, score: 200.0, average: 40.86 SAVING
# episode: 218/600, score: 364.0, average: 47.68 SAVING
# episode: 219/600, score: 95.0, average: 49.10 SAVING
# episode: 220/600, score: 102.0, average: 50.86 SAVING
# episode: 221/600, score: 79.0, average: 52.00 SAVING
# episode: 222/600, score: 65.0, average: 52.80 SAVING
# episode: 223/600, score: 84.0, average: 54.06 SAVING
# episode: 224/600, score: 75.0, average: 55.12 SAVING
# episode: 225/600, score: 107.0, average: 56.84 SAVING
# episode: 226/600, score: 129.0, average: 59.02 SAVING
# episode: 227/600, score: 100.0, average: 60.62 SAVING
# episode: 228/600, score: 100.0, average: 62.20 SAVING
# episode: 229/600, score: 129.0, average: 64.32 SAVING
# episode: 230/600, score: 148.0, average: 66.88 SAVING
# episode: 231/600, score: 191.0, average: 70.26 SAVING
# episode: 232/600, score: 1000.0, average: 89.70 SAVING
# episode: 233/600, score: 349.0, average: 95.72 SAVING
# episode: 234/600, score: 1000.0, average: 115.00 SAVING
# episode: 235/600, score: 409.0, average: 122.68 SAVING
# episode: 236/600, score: 124.0, average: 124.38 SAVING
# episode: 237/600, score: 169.0, average: 127.12 SAVING
# episode: 238/600, score: 350.0, average: 132.96 SAVING
# episode: 239/600, score: 398.0, average: 140.38 SAVING
# episode: 240/600, score: 383.0, average: 147.22 SAVING
# episode: 241/600, score: 1000.0, average: 166.56 SAVING
# episode: 242/600, score: 1000.0, average: 185.94 SAVING
# episode: 243/600, score: 569.0, average: 196.82 SAVING
# episode: 244/600, score: 1000.0, average: 216.10 SAVING
# episode: 245/600, score: 144.0, average: 218.28 SAVING
# episode: 246/600, score: 124.0, average: 220.30 SAVING
# episode: 247/600, score: 125.0, average: 221.52 SAVING
# episode: 248/600, score: 131.0, average: 223.70 SAVING
# episode: 249/600, score: 270.0, average: 228.28 SAVING
# episode: 250/600, score: 210.0, average: 231.86 SAVING
# episode: 251/600, score: 1000.0, average: 251.14 SAVING
# episode: 252/600, score: 731.0, average: 265.20 SAVING
# episode: 253/600, score: 320.0, average: 270.74 SAVING
# episode: 254/600, score: 229.0, average: 274.56 SAVING
# episode: 255/600, score: 398.0, average: 281.96 SAVING
# episode: 256/600, score: 147.0, average: 284.26 SAVING
# episode: 257/600, score: 239.0, average: 288.36 SAVING
# episode: 258/600, score: 143.0, average: 290.68 SAVING
# episode: 259/600, score: 1000.0, average: 310.08 SAVING
# episode: 260/600, score: 1000.0, average: 329.22 SAVING
# episode: 261/600, score: 100.0, average: 330.30 SAVING
# episode: 262/600, score: 119.0, average: 331.04 SAVING
# episode: 263/600, score: 120.0, average: 331.50 SAVING
# episode: 264/600, score: 99.0, average: 331.76 SAVING
# episode: 265/600, score: 105.0, average: 331.92 SAVING
# episode: 266/600, score: 56.0, average: 330.58
# episode: 267/600, score: 51.0, average: 327.60
# episode: 268/600, score: 67.0, average: 321.66
# episode: 269/600, score: 57.0, average: 320.90
# episode: 270/600, score: 82.0, average: 320.50
# episode: 271/600, score: 53.0, average: 319.98
# episode: 272/600, score: 52.0, average: 319.72
# episode: 273/600, score: 49.0, average: 319.02
# episode: 274/600, score: 52.0, average: 318.56
# episode: 275/600, score: 51.0, average: 317.44
# episode: 276/600, score: 13.0, average: 315.12
# episode: 277/600, score: 145.0, average: 316.02
# episode: 278/600, score: 101.0, average: 316.04
# episode: 279/600, score: 42.0, average: 314.30
# episode: 280/600, score: 49.0, average: 312.32
# episode: 281/600, score: 42.0, average: 309.34
# episode: 282/600, score: 121.0, average: 291.76
# episode: 283/600, score: 206.0, average: 288.90
# episode: 284/600, score: 132.0, average: 271.54
# episode: 285/600, score: 48.0, average: 264.32
# episode: 286/600, score: 1000.0, average: 281.84
# episode: 287/600, score: 562.0, average: 289.70
# episode: 288/600, score: 42.0, average: 283.54
# episode: 289/600, score: 41.0, average: 276.40
# episode: 290/600, score: 48.0, average: 269.70
# episode: 291/600, score: 40.0, average: 250.50
# episode: 292/600, score: 43.0, average: 231.36
# episode: 293/600, score: 49.0, average: 220.96
# episode: 294/600, score: 42.0, average: 201.80
# episode: 295/600, score: 45.0, average: 199.82
# episode: 296/600, score: 45.0, average: 198.24
# episode: 297/600, score: 49.0, average: 196.72
# episode: 298/600, score: 58.0, average: 195.26
# episode: 299/600, score: 1000.0, average: 209.86
# episode: 300/600, score: 1000.0, average: 225.66
# episode: 301/600, score: 1000.0, average: 225.66
# episode: 302/600, score: 1000.0, average: 231.04
# episode: 303/600, score: 1000.0, average: 244.64
# episode: 304/600, score: 1000.0, average: 260.06
# episode: 305/600, score: 1000.0, average: 272.10
# episode: 306/600, score: 1000.0, average: 289.16
# episode: 307/600, score: 1000.0, average: 304.38
# episode: 308/600, score: 1000.0, average: 321.52
# episode: 309/600, score: 1000.0, average: 321.52
# episode: 310/600, score: 1000.0, average: 321.52
# episode: 311/600, score: 837.0, average: 336.26 SAVING
# episode: 312/600, score: 1000.0, average: 353.88 SAVING
# episode: 313/600, score: 1000.0, average: 371.48 SAVING
# episode: 314/600, score: 1000.0, average: 389.50 SAVING
# episode: 315/600, score: 183.0, average: 391.06 SAVING
# episode: 316/600, score: 217.0, average: 394.28 SAVING
# episode: 317/600, score: 220.0, average: 397.66 SAVING
# episode: 318/600, score: 243.0, average: 401.18 SAVING
# episode: 319/600, score: 288.0, average: 405.80 SAVING
# episode: 320/600, score: 105.0, average: 406.26 SAVING
# episode: 321/600, score: 347.0, average: 412.14 SAVING
# episode: 322/600, score: 88.0, average: 412.86 SAVING
# episode: 323/600, score: 95.0, average: 413.78 SAVING
# episode: 324/600, score: 72.0, average: 414.18 SAVING
# episode: 325/600, score: 99.0, average: 415.14 SAVING
# episode: 326/600, score: 65.0, average: 416.18 SAVING
# episode: 327/600, score: 654.0, average: 426.36 SAVING
# episode: 328/600, score: 126.0, average: 426.86 SAVING
# episode: 329/600, score: 1000.0, average: 446.02 SAVING
# episode: 330/600, score: 1000.0, average: 465.04 SAVING
# episode: 331/600, score: 918.0, average: 482.56 SAVING
# episode: 332/600, score: 47.0, average: 481.08
# episode: 333/600, score: 49.0, average: 477.94
# episode: 334/600, score: 45.0, average: 476.20
# episode: 335/600, score: 59.0, average: 476.42
# episode: 336/600, score: 43.0, average: 457.28
# episode: 337/600, score: 52.0, average: 447.08
# episode: 338/600, score: 58.0, average: 447.40
# episode: 339/600, score: 54.0, average: 447.66
# episode: 340/600, score: 57.0, average: 447.84
# episode: 341/600, score: 80.0, average: 448.64
# episode: 342/600, score: 71.0, average: 449.20
# episode: 343/600, score: 64.0, average: 449.50
# episode: 344/600, score: 67.0, average: 450.00
# episode: 345/600, score: 58.0, average: 450.26
# episode: 346/600, score: 1000.0, average: 469.36
# episode: 347/600, score: 1000.0, average: 488.38 SAVING
# episode: 348/600, score: 1000.0, average: 507.22 SAVING
# episode: 349/600, score: 1000.0, average: 507.22 SAVING
# episode: 350/600, score: 1000.0, average: 507.22 SAVING
# episode: 351/600, score: 1000.0, average: 507.22 SAVING
# episode: 352/600, score: 1000.0, average: 507.22 SAVING
# episode: 353/600, score: 1000.0, average: 507.22 SAVING
# episode: 354/600, score: 1000.0, average: 507.22 SAVING
# episode: 355/600, score: 1000.0, average: 507.22 SAVING
# episode: 356/600, score: 1000.0, average: 507.22 SAVING
# episode: 357/600, score: 1000.0, average: 507.22 SAVING
# episode: 358/600, score: 1000.0, average: 507.22 SAVING
# episode: 359/600, score: 1000.0, average: 507.22 SAVING
# episode: 360/600, score: 684.0, average: 500.90
# episode: 361/600, score: 416.0, average: 492.48
# episode: 362/600, score: 237.0, average: 477.22
# episode: 363/600, score: 333.0, average: 463.88
# episode: 364/600, score: 968.0, average: 463.24
# episode: 365/600, score: 215.0, average: 463.88
# episode: 366/600, score: 205.0, average: 463.64
# episode: 367/600, score: 522.0, average: 469.68
# episode: 368/600, score: 56.0, average: 465.94
# episode: 369/600, score: 64.0, average: 461.46
# episode: 370/600, score: 74.0, average: 460.84
# episode: 371/600, score: 53.0, average: 454.96
# episode: 372/600, score: 79.0, average: 454.78
# episode: 373/600, score: 68.0, average: 454.24
# episode: 374/600, score: 62.0, average: 454.04
# episode: 375/600, score: 104.0, average: 454.14
# episode: 376/600, score: 192.0, average: 456.68
# episode: 377/600, score: 347.0, average: 450.54
# episode: 378/600, score: 263.0, average: 453.28
# episode: 379/600, score: 283.0, average: 438.94
# episode: 380/600, score: 1000.0, average: 438.94
# episode: 381/600, score: 1000.0, average: 440.58
# episode: 382/600, score: 1000.0, average: 459.64
# episode: 383/600, score: 1000.0, average: 478.66
# episode: 384/600, score: 1000.0, average: 497.76
# episode: 385/600, score: 1000.0, average: 516.58 SAVING
# episode: 386/600, score: 1000.0, average: 535.72 SAVING
# episode: 387/600, score: 1000.0, average: 554.68 SAVING
# episode: 388/600, score: 1000.0, average: 573.52 SAVING
# episode: 389/600, score: 1000.0, average: 592.44 SAVING
# episode: 390/600, score: 1000.0, average: 611.30 SAVING
# episode: 391/600, score: 1000.0, average: 629.70 SAVING
# episode: 392/600, score: 860.0, average: 645.48 SAVING
# episode: 393/600, score: 1000.0, average: 664.20 SAVING
# episode: 394/600, score: 821.0, average: 679.28 SAVING
# episode: 395/600, score: 1000.0, average: 698.12 SAVING
# episode: 396/600, score: 1000.0, average: 698.12 SAVING
# episode: 397/600, score: 1000.0, average: 698.12 SAVING
# episode: 398/600, score: 1000.0, average: 698.12 SAVING
# episode: 399/600, score: 1000.0, average: 698.12 SAVING
# episode: 400/600, score: 1000.0, average: 698.12 SAVING
# episode: 401/600, score: 1000.0, average: 698.12 SAVING
# episode: 402/600, score: 1000.0, average: 698.12 SAVING
# episode: 403/600, score: 332.0, average: 684.76
# episode: 404/600, score: 349.0, average: 671.74
# episode: 405/600, score: 1000.0, average: 671.74
# episode: 406/600, score: 1000.0, average: 671.74
# episode: 407/600, score: 1000.0, average: 671.74
# episode: 408/600, score: 1000.0, average: 671.74
# episode: 409/600, score: 1000.0, average: 671.74
# episode: 410/600, score: 1000.0, average: 678.06
# episode: 411/600, score: 1000.0, average: 689.74
# episode: 412/600, score: 1000.0, average: 705.00 SAVING
# episode: 413/600, score: 1000.0, average: 718.34 SAVING
# episode: 414/600, score: 1000.0, average: 718.98 SAVING
# episode: 415/600, score: 1000.0, average: 734.68 SAVING
# episode: 416/600, score: 1000.0, average: 750.58 SAVING
# episode: 417/600, score: 1000.0, average: 760.14 SAVING
# episode: 418/600, score: 1000.0, average: 779.02 SAVING
# episode: 419/600, score: 1000.0, average: 797.74 SAVING
# episode: 420/600, score: 1000.0, average: 816.26 SAVING
# episode: 421/600, score: 1000.0, average: 835.20 SAVING
# episode: 422/600, score: 1000.0, average: 853.62 SAVING
# episode: 423/600, score: 1000.0, average: 872.26 SAVING
# episode: 424/600, score: 1000.0, average: 891.02 SAVING
# episode: 425/600, score: 596.0, average: 900.86 SAVING
# episode: 426/600, score: 81.0, average: 898.64
# episode: 427/600, score: 67.0, average: 893.04
# episode: 428/600, score: 71.0, average: 889.20
# episode: 429/600, score: 61.0, average: 884.76
# episode: 430/600, score: 42.0, average: 865.60
# episode: 431/600, score: 56.0, average: 846.72
# episode: 432/600, score: 69.0, average: 828.10
# episode: 433/600, score: 1000.0, average: 828.10
# episode: 434/600, score: 1000.0, average: 828.10
# episode: 435/600, score: 1000.0, average: 828.10
# episode: 436/600, score: 1000.0, average: 828.10
# episode: 437/600, score: 1000.0, average: 828.10
# episode: 438/600, score: 1000.0, average: 828.10
# episode: 439/600, score: 219.0, average: 812.48
# episode: 440/600, score: 7.0, average: 792.62
# episode: 441/600, score: 221.0, average: 777.04
# episode: 442/600, score: 12.0, average: 760.08
# episode: 443/600, score: 7.0, average: 740.22
# episode: 444/600, score: 115.0, average: 726.10
# episode: 445/600, score: 10.0, average: 706.30
# episode: 446/600, score: 13.0, average: 686.56
# episode: 447/600, score: 26.0, average: 667.08
# episode: 448/600, score: 7.0, average: 647.22
# episode: 449/600, score: 61.0, average: 628.44
# episode: 450/600, score: 1000.0, average: 628.44
# episode: 451/600, score: 1000.0, average: 628.44
# episode: 452/600, score: 556.0, average: 619.56
# episode: 453/600, score: 42.0, average: 613.76
# episode: 454/600, score: 43.0, average: 607.64
# episode: 455/600, score: 41.0, average: 588.46
# episode: 456/600, score: 45.0, average: 569.36
# episode: 457/600, score: 7.0, average: 549.50
# episode: 458/600, score: 41.0, average: 530.32
# episode: 459/600, score: 43.0, average: 511.18
# episode: 460/600, score: 42.0, average: 492.02
# episode: 461/600, score: 38.0, average: 472.78
# episode: 462/600, score: 42.0, average: 453.62
# episode: 463/600, score: 44.0, average: 434.50
# episode: 464/600, score: 44.0, average: 415.38
# episode: 465/600, score: 1000.0, average: 415.38
# episode: 466/600, score: 1000.0, average: 415.38
# episode: 467/600, score: 1000.0, average: 415.38
# episode: 468/600, score: 1000.0, average: 415.38
# episode: 469/600, score: 687.0, average: 409.12
# episode: 470/600, score: 52.0, average: 390.16
# episode: 471/600, score: 57.0, average: 371.30
# episode: 472/600, score: 52.0, average: 352.34
# episode: 473/600, score: 53.0, average: 333.40
# episode: 474/600, score: 51.0, average: 314.42
# episode: 475/600, score: 68.0, average: 303.86
# episode: 476/600, score: 59.0, average: 303.42
# episode: 477/600, score: 55.0, average: 303.18
# episode: 478/600, score: 1000.0, average: 321.76
# episode: 479/600, score: 73.0, average: 322.00
# episode: 480/600, score: 1000.0, average: 341.16
# episode: 481/600, score: 7.0, average: 340.18
# episode: 482/600, score: 7.0, average: 338.94
# episode: 483/600, score: 6.0, average: 319.06
# episode: 484/600, score: 7.0, average: 299.20
# episode: 485/600, score: 6.0, average: 279.32
# episode: 486/600, score: 7.0, average: 259.46
# episode: 487/600, score: 142.0, average: 242.30
# episode: 488/600, score: 6.0, average: 222.42
# episode: 489/600, score: 153.0, average: 221.10
# episode: 490/600, score: 12.0, average: 221.20
# episode: 491/600, score: 7.0, average: 216.92
# episode: 492/600, score: 6.0, average: 216.80
# episode: 493/600, score: 8.0, average: 216.82
# episode: 494/600, score: 7.0, average: 214.66
# episode: 495/600, score: 111.0, average: 216.68
# episode: 496/600, score: 7.0, average: 216.56
# episode: 497/600, score: 6.0, average: 216.16
# episode: 498/600, score: 12.0, average: 216.26
# episode: 499/600, score: 7.0, average: 215.18
# episode: 500/600, score: 9.0, average: 195.36
# episode: 501/600, score: 6.0, average: 175.48
# episode: 502/600, score: 6.0, average: 164.48
# episode: 503/600, score: 6.0, average: 163.76
# episode: 504/600, score: 6.0, average: 163.02
# episode: 505/600, score: 6.0, average: 162.32
# episode: 506/600, score: 9.0, average: 161.60
# episode: 507/600, score: 7.0, average: 161.60
# episode: 508/600, score: 7.0, average: 160.92
# episode: 509/600, score: 5.0, average: 160.16
# episode: 510/600, score: 6.0, average: 159.44
# episode: 511/600, score: 9.0, average: 158.86
# episode: 512/600, score: 6.0, average: 158.14
# episode: 513/600, score: 5.0, average: 157.36
# episode: 514/600, score: 6.0, average: 156.60
# episode: 515/600, score: 5.0, average: 136.70
# episode: 516/600, score: 6.0, average: 116.82
# episode: 517/600, score: 5.0, average: 96.92
# episode: 518/600, score: 6.0, average: 77.04
# episode: 519/600, score: 5.0, average: 63.40
# episode: 520/600, score: 6.0, average: 62.48
# episode: 521/600, score: 7.0, average: 61.48
# episode: 522/600, score: 8.0, average: 60.60
# episode: 523/600, score: 6.0, average: 59.66
# episode: 524/600, score: 104.0, average: 60.72
# episode: 525/600, score: 5.0, average: 59.46
# episode: 526/600, score: 5.0, average: 58.38
# episode: 527/600, score: 6.0, average: 57.40
# episode: 528/600, score: 6.0, average: 37.52
# episode: 529/600, score: 8.0, average: 36.22
# episode: 530/600, score: 6.0, average: 16.34
# episode: 531/600, score: 6.0, average: 16.32
# episode: 532/600, score: 5.0, average: 16.28
# episode: 533/600, score: 8.0, average: 16.32
# episode: 534/600, score: 6.0, average: 16.30
# episode: 535/600, score: 5.0, average: 16.28
# episode: 536/600, score: 6.0, average: 16.26
# episode: 537/600, score: 10.0, average: 13.62
# episode: 538/600, score: 6.0, average: 13.62
# episode: 539/600, score: 6.0, average: 10.68
# episode: 540/600, score: 7.0, average: 10.58
# episode: 541/600, score: 14.0, average: 10.72
# episode: 542/600, score: 6.0, average: 10.72
# episode: 543/600, score: 7.0, average: 10.70
# episode: 544/600, score: 6.0, average: 10.68
# episode: 545/600, score: 6.0, average: 8.58
# episode: 546/600, score: 7.0, average: 8.58
# episode: 547/600, score: 6.0, average: 8.58
# episode: 548/600, score: 8.0, average: 8.50
# episode: 549/600, score: 6.0, average: 8.48
# episode: 550/600, score: 8.0, average: 8.46
# episode: 551/600, score: 5.0, average: 8.44
# episode: 552/600, score: 7.0, average: 8.46
# episode: 553/600, score: 6.0, average: 8.46
# episode: 554/600, score: 5.0, average: 8.44
# episode: 555/600, score: 6.0, average: 8.44
# episode: 556/600, score: 10.0, average: 8.46
# episode: 557/600, score: 5.0, average: 8.42
# episode: 558/600, score: 5.0, average: 8.38
# episode: 559/600, score: 6.0, average: 8.40
# episode: 560/600, score: 6.0, average: 8.40
# episode: 561/600, score: 7.0, average: 8.36
# episode: 562/600, score: 7.0, average: 8.38
# episode: 563/600, score: 552.0, average: 19.32
# episode: 564/600, score: 9.0, average: 19.38
# episode: 565/600, score: 7.0, average: 19.42
# episode: 566/600, score: 10.0, average: 19.50
# episode: 567/600, score: 195.0, average: 23.30
# episode: 568/600, score: 153.0, average: 26.24
# episode: 569/600, score: 11.0, average: 26.36
# episode: 570/600, score: 1000.0, average: 46.24
# episode: 571/600, score: 615.0, average: 58.40
# episode: 572/600, score: 5.0, average: 58.34
# episode: 573/600, score: 7.0, average: 58.36
# episode: 574/600, score: 11.0, average: 56.50
# episode: 575/600, score: 9.0, average: 56.58
# episode: 576/600, score: 8.0, average: 56.64
# episode: 577/600, score: 8.0, average: 56.68
# episode: 578/600, score: 6.0, average: 56.68
# episode: 579/600, score: 7.0, average: 56.66
# episode: 580/600, score: 7.0, average: 56.68
# episode: 581/600, score: 6.0, average: 56.68
# episode: 582/600, score: 79.0, average: 58.16
# episode: 583/600, score: 10.0, average: 58.20
# episode: 584/600, score: 5.0, average: 58.18
# episode: 585/600, score: 6.0, average: 58.20
# episode: 586/600, score: 8.0, average: 58.24
# episode: 587/600, score: 68.0, average: 59.40
# episode: 588/600, score: 8.0, average: 59.44
# episode: 589/600, score: 8.0, average: 59.48
# episode: 590/600, score: 7.0, average: 59.48
# episode: 591/600, score: 5.0, average: 59.30
# episode: 592/600, score: 6.0, average: 59.30
# episode: 593/600, score: 5.0, average: 59.26
# episode: 594/600, score: 8.0, average: 59.30
# episode: 595/600, score: 80.0, average: 60.78
# episode: 596/600, score: 8.0, average: 60.80
# episode: 597/600, score: 66.0, average: 62.00
# episode: 598/600, score: 8.0, average: 62.00
# episode: 599/600, score: 12.0, average: 62.12
# episode: 600/600, score: 63.0, average: 63.22
# episode: 601/600, score: 77.0, average: 64.66

# %%
agent.test()
# Out:
# Creating window glfw
# episode: 0/50, score: 73.0, average74.1
# episode: 1/50, score: 72.0, average74.04
# episode: 2/50, score: 76.0, average74.08
# episode: 3/50, score: 75.0, average74.06
# episode: 4/50, score: 76.0, average74.14
# episode: 5/50, score: 74.0, average74.18
# episode: 6/50, score: 75.0, average74.24
# episode: 7/50, score: 73.0, average74.26
# episode: 8/50, score: 74.0, average74.22
# episode: 9/50, score: 72.0, average74.16
# episode: 10/50, score: 75.0, average74.2
# episode: 11/50, score: 75.0, average74.24
# episode: 12/50, score: 75.0, average74.26
# episode: 13/50, score: 73.0, average74.24
# episode: 14/50, score: 76.0, average74.32
# episode: 15/50, score: 72.0, average74.26
# episode: 16/50, score: 76.0, average74.34
# episode: 17/50, score: 76.0, average74.42
# episode: 18/50, score: 76.0, average74.46
# episode: 19/50, score: 72.0, average74.4
# episode: 20/50, score: 72.0, average74.4
# episode: 21/50, score: 76.0, average74.42
# episode: 22/50, score: 75.0, average74.46
# episode: 23/50, score: 74.0, average74.44
# episode: 24/50, score: 72.0, average74.38
# episode: 25/50, score: 73.0, average74.38
# episode: 26/50, score: 74.0, average74.34
# episode: 27/50, score: 75.0, average74.34
# episode: 28/50, score: 72.0, average74.28
# episode: 29/50, score: 75.0, average74.34
# episode: 30/50, score: 74.0, average74.38
# episode: 31/50, score: 72.0, average74.34
# episode: 32/50, score: 76.0, average74.36
# episode: 33/50, score: 72.0, average74.3
# episode: 34/50, score: 72.0, average74.26
# episode: 35/50, score: 72.0, average74.22
# episode: 36/50, score: 74.0, average74.18
# episode: 37/50, score: 72.0, average74.1
# episode: 38/50, score: 73.0, average74.06
# episode: 39/50, score: 75.0, average74.1
# episode: 40/50, score: 72.0, average74.04
# episode: 41/50, score: 72.0, average74.0
# episode: 42/50, score: 73.0, average73.94
# episode: 43/50, score: 72.0, average73.92
# episode: 44/50, score: 75.0, average73.92
# episode: 45/50, score: 75.0, average73.9
# episode: 46/50, score: 73.0, average73.86
# episode: 47/50, score: 73.0, average73.82
# episode: 48/50, score: 73.0, average73.78
# episode: 49/50, score: 75.0, average73.78
# episode: 50/50, score: 75.0, average73.82
